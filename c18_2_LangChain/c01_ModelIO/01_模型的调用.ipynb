# %%
import os

import dotenv

"""
LangChain作为一个工具，不提供任何LLMs，而是依赖于第三方集成各种大模型
1.模型调用的分类
    角度1：按照模型功能的不同
        非对话型模型：text model
        对话模型：char model（推荐）
        嵌入模型：embedding model
    角度2：按照模型调用时，参数书写的位置不同（api-key,base_url,model-name）
        硬编码的方式：将参数书写在代码中
        使用环境变量的方式
        使用配置文件的方式（推荐）
    角度3：具体api的调用
        使用langCHain提供的API（推荐）
        使用openAi
        使用其它大模型自家提供的api
"""

# %%
# 角度1
# 非对话型模型
"""
LLMs，也叫text model，非对话模型，是许多语言模型应用程序的支柱
输入：接受文本字符串或promptValue对象
输出：总是返回文本字符串
适用场景：仅需单次文本生成任务（如摘要生成，翻译，代码生成，单次问题）或对接不支持消息结构的旧模型（如部分本地部署模型）
不支持多轮对话上下文：每次调用独立处理输入，无法自动关联历史对话（需手动拼接历史文本）
局限性：无法处理角色分工或复杂对话逻辑
"""


# 对话模型（chat models）
"""
chatModels，也叫聊天模型，对话模型，底层使用LLMS
大语言模型调用，以chatModel为主
输入：接受消息列表List[BaseMessage]或PromptValue，每条需要需指定角色（如SystemMessage，HumanMessage，AIMessage）
输出：总是返回带角色的消息对象（BaseMessage子类），通常是AIMessage
原生支持多轮对话：通过消息列表维护上下文，模型可基于完整对话历史生成回复
适用场景：对话系统（如客服机器人，长期交互的AI助手）
"""

# embedding model（嵌入模型）
"""
embedding model：也叫文本嵌入模型，这些模型将文本作为输入并返回浮点数列表，也就是embedding
"""

# %%
# 角度2

# 硬编码
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAI


# 调用非对话模型
# llms = OpenAI()

# 调用对话模型
chat_model = ChatOpenAI(
    model_name="GLM-5.1",# 默认使用的是gpt3.5
    base_url="xxxxx",
    api_key="xxxxxxxx",
)

# 调用模型
resp = chat_model.invoke("什么是langChain？")

# 查看响应文本
print(resp.content)
# Out:
# **LangChain** 是一个用于**开发由大语言模型（LLM，如 ChatGPT、GLM等）驱动的应用程序的开源框架**。
#
# 如果用一句话来概括：**LangChain 是连接“大语言模型”和“现实世界的数据与工具”的桥梁（或者说“胶水”）。**
#
# 为了让你更容易理解，我们可以从它解决的问题、核心组件以及应用场景三个方面来拆解。
#
# ---
#
# ### 1. 为什么需要 LangChain？（它解决了什么问题）
#
# 大语言模型（LLM）虽然很强大，但它们有几个明显的缺陷：
# *   **知识停滞**：它们的知识停留在训练完成的那一天，不知道最新发生的新闻。
# *   **缺乏私有数据**：它们不知道你公司的内部文档、你的个人笔记或数据库里的信息。
# *   **无法执行动作**：它们只能“说话”，不能帮你发邮件、查数据库、或者联网搜索。
# *   **记忆力有限**：模型本身是无状态的，你发一句话，它回一句，它记不住上一轮的对话（除非你每次把历史记录都发给它）。
#
# **LangChain 的出现就是为了解决这些痛点。** 它提供了一套标准的工具和接口，帮开发者把 LLM 与外部数据源、计算工具以及记忆模块轻松地连接起来。
#
# ---
#
# ### 2. LangChain 的六大核心组件
#
# LangChain 的设计非常模块化，就像乐高积木一样，它的核心组件包括：
#
# 1.  **Models（模型）**：
#     LangChain 提供了一个统一的接口，让你不需要修改太多代码，就能轻松切换各种底层大模型（比如从 OpenAI 的 GPT-4 切换到智谱的GLM，或开源的 Llama）。
# 2.  **Prompts（提示词）**：
#     帮你管理和优化对模型说的话。它提供了“提示词模板”，让你不需要每次都把指令重写一遍，只需填入变量即可。
# 3.  **Memory（记忆）**：
#     赋予大模型“记忆力”。它可以记住你们上文的对话内容，使得多轮对话（如聊天机器人）成为可能。
# 4.  **Indexes / Retrieval（索引与检索 / RAG）**：
# ...

# %%
from langchain_openai import OpenAI


# 调用非对话模型
llm = OpenAI(
    model_name="GLM-5.1",# 默认使用的是gpt3.5
    base_url="xxxxxxx",
    api_key="xxxxxxxx",
)


# 调用模型
resp = llm.invoke("什么是langChain？")

# 查看响应文本
print(resp)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[30], line 12
#       5 llm = OpenAI(
#       6     base_url="https://api.openai-proxy.org/v1",
#       7     api_key="sk-k5T6xkACAdsWxZbpXT27zA2z7jkzmN3are1KaVnt5VZC9ArK",
#       8 )
#      11 # 调用模型
# ---> 12 resp = llm.invoke("什么是langChain？")
#      14 # 查看响应文本
#      15 print(resp)
#
# File D:\anaconda\envs\pyth310\lib\site-packages\langchain_core\language_models\llms.py:389, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     378 @override
#     379 def invoke(
#     380     self,
#    (...)
#     385     **kwargs: Any,
#     386 ) -> str:
#     387     config = ensure_config(config)
#     388     return (
# --> 389         self.generate_prompt(
#     390             [self._convert_input(input)],
#     391             stop=stop,
#     392             callbacks=config.get("callbacks"),
# ...

# %%
# 环境变量

# 使用环境变量的方式，在jupyter中执行不合适，需要在.py中执行
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAI


# 调用非对话模型
# llms = OpenAI()

# 调用对话模型
chat_model = ChatOpenAI(
    model_name="GLM-5.1",# 默认使用的是gpt3.5
    base_url=os.environ['Z-AI-URL'],
    api_key=os.environ['Z-AI-KEY'],
)

# 调用模型
resp = chat_model.invoke("您好，1 + 1 等于几？")

# 查看响应文本
print(resp.content)

# %%
# 使用.env配置文件

import os
import dotenv

dotenv.load_dotenv()

from langchain_openai import ChatOpenAI

# 调用对话模型
chat_model = ChatOpenAI(
    model_name="GLM-5.1",# 默认使用的是gpt3.5
    base_url=os.environ['Z-AI-URL-ENV'],
    api_key=os.environ['Z-AI-KEY-ENV'],
)

# 调用模型
resp = chat_model.invoke("您好，1 + 1 等于几？")

# 查看响应文本
print(resp.content)
# Out:
# 您好！1 + 1 等于 **2**。

# %%
# 体会其它参数的使用
"""
temperature:
    温度，控制生成文本的“随机性”，取值范围为0～1。
    值越低 → 输出越确定、保守（适合事实回答）
    值越高 → 输出越多样、有创意（适合创意写作）
    通常，根据需要设置如下：
    精确模式（0.5或更低）：生成的文本更加安全可靠，但可能缺乏创意和多样性。
    平衡模式（通常是0.8）：生成的文本通常既有一定的多样性，又能保持较好的连贯性和准确性。
    创意模式（通常是1）：生成的文本更有创意，但也更容易出现语法错误或不合逻辑的内容。
max_tokens:
    限制生成文本的最大长度，防止输出过长。
"""

import os
import dotenv


from langchain_openai import ChatOpenAI


# 调用对话模型
chat_model = ChatOpenAI(
    model_name="gpt-4.1-mini",# 默认使用的是gpt3.5
    base_url="xxxx",
    api_key="xxxxxx",
    temperature= 0.8,
    max_tokens=20
)

# 调用模型
resp = chat_model.invoke("什么是langChain？")

# 查看响应文本
print(resp.content)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[29], line 32
#      23 chat_model = ChatOpenAI(
#      24     model_name="gpt-4.1-mini",# 默认使用的是gpt3.5
#      25     base_url="https://api.openai-proxy.org/v1",
#    (...)
#      28     max_tokens=10
#      29 )
#      31 # 调用模型
# ---> 32 resp = chat_model.invoke("什么是langChain？")
#      34 # 查看响应文本
#      35 print(resp.content)
#
# File D:\anaconda\envs\pyth310\lib\site-packages\langchain_core\language_models\chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)
#     390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
# ...

# %%
# 其它ai，我白嫖的别人的智谱，就用智谱吧
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage

# 创建 LLM 实例
llm = ChatOpenAI(
    temperature=0.7,
    max_tokens=20,
    model="glm-5.1",
    openai_api_key="xxxxx",
    openai_api_base="xxxxx"
)

# 创建消息
messages = [
    SystemMessage(content="你是一个有用的 AI 助手"),
    HumanMessage(content="请介绍一下人工智能的发展历程")
]

# 调用模型
response = llm(messages)
print(response.content)
# Out:
# 人工智能（Artificial Intelligence, AI）的发展历程是一部充满激情、低谷与突破的科技史诗。从最初的哲学幻想，到如今深刻改变人类社会的生成式AI，其发展大致可以划分为以下几个关键阶段：
#
# ### 1. 孕育期（1956年之前）：思想与理论的萌芽
# 在“人工智能”这个词出现之前，人类就已经开始构思机器智能的可能。
# * **图灵测试（1950年）**：阿兰·图灵发表了著名论文《计算机器与智能》，提出了著名的“图灵测试”——如果一台机器能与人类进行对话而不被辨认出其机器身份，那么这台机器就具有智能。
# * **早期理论**：麦卡洛克和皮茨提出了最早的神经网络数学模型（M-P模型），为后来的神经网络发展奠定了理论基础。
#
# ### 2. 诞生与第一次黄金期（1956年 - 1970年代初）：AI的创世纪
# * **达特茅斯会议（1956年）**：约翰·麦卡锡、马文·明斯基、克劳德·香农等人在达特茅斯学院开了一场为期两个月的研讨会。会议上**首次正式提出了“人工智能”这一术语**，标志着AI作为一门独立学科的诞生。
# * **主要成就**：这一时期属于“符号主义”时代，研究者认为只要用逻辑规则教计算机，它就能思考。开发出了代数应用、几何定理证明器，以及最早的聊天机器人ELIZA（基于简单模式匹配模拟心理医生）。
# * **盲目乐观**：当时学者们极度乐观，认为“二十年内机器将能完成人能做到的一切工作”。
#
# ### 3. 第一次AI寒冬（1970年代中 - 1980年代初）：现实的骨感
# * **瓶颈**：人们发现早期的AI只能解决“玩具问题”。当面对现实世界的复杂问题时，出现了“组合爆炸”——计算量随问题规模呈指数级增长，当时的算力根本无法支撑。
# * **莫拉维克悖论**：困难的问题（如逻辑推理）对AI很容易，但对人类很难；而简单的问题（如视觉、走路、认人）对人类很容易，对AI却难如登天。
# * **结果**：承诺的目标迟迟无法实现，政府和机构（如美国DARPA、英国政府）大幅削减AI研究经费，行业进入第一次寒冬。
#
# ### 4. 专家系统与第二次繁荣（1980年代）：知识的力量
# ...

# %%
# 总结
"""
后续的各种模型测试，都基于如下的模型展开
非对话模型
对话模型
"""
