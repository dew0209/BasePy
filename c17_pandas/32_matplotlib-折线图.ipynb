# %%
from calendar import month

"""
折线图：plot
条形图：bar
饼图：pie
散点图：scatter
箱线图：boxplot
组合图
"""

# %%
# 折线图

import matplotlib.pyplot as plt
from matplotlib import rcParams # 字体

# 设置字体
rcParams['font.family'] = ['SimHei']
# 创建图表，设置大小
plt.figure(figsize=(10,5))


month = ['1月','2月','3月','4月']
sales = [100,150,80,130]
# 绘制折线图
plt.plot(month,sales,label='产品A',color='orange',marker='o',linestyle='--',linewidth=2)
# 添加标题
plt.title('2025年销售趋势',color='red',fontsize=10)
# 添加坐标轴的标签
plt.xlabel('月份',fontsize=10)
plt.ylabel('销售额',fontsize=10)
# 添加图例
plt.legend(loc='upper left',fontsize=10)
# 添加网格线
# plt.grid(axis='x')
# plt.grid(axis='y')
plt.grid(True,alpha=0.1,color='blue',linestyle='--')

# 自定义刻度字体大小
plt.xticks(rotation=60,fontsize=5)
plt.yticks(fontsize=10)

# 设置y轴范围
plt.ylim(0,160)

# 在每个数据点上显示数值

for x,y in zip(month,sales):
    plt.text(x,y + 1,str(y),ha='center',va='bottom',fontsize=10)

# 显示图表
plt.show()
