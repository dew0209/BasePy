# %%
"""
属性                  说明
index                 DataFrame的行索引
values                DataFrame的值
dtypes                DataFrame的元素类型
shape                 DataFrame的形状
ndim                  DataFrame的维度
size                  DataFrame的元素个数
columns               DataFrame的列标签
loc[]                 显式索引，按行列标签索引或切片
iloc[]                隐式索引，按行列位置索引或切片
at[]                  使用行列标签访问单个元素
iat[]                 使用列位置访问单个元素
T                     行列转置
"""

# %%
import pandas as pd
import numpy as np

# 通过Series来创建
df = pd.DataFrame({"id":[1,2,3,4,5],
                   "name":['tom','jack','bob','alice','zoom'],
                   "age":[20,30,40,50,10]
                   },index=[f"学生{i}" for i in range(1,6)],columns=['id','age','name'])
print(df)
# Out:
#      id  age   name
# 学生1   1   20    tom
# 学生2   2   30   jack
# 学生3   3   40    bob
# 学生4   4   50  alice
# 学生5   5   10   zoom

# %%
print('行索引')
print(df.index)
print('列标签')
print(df.columns)
print('值')
print(df.values)
print('维度')
print(df.ndim)
print('数据类型')
print(df.dtypes)
print('转置')
print(df.T)
# Out:
# 行索引
# Index(['学生1', '学生2', '学生3', '学生4', '学生5'], dtype='str')
# 列标签
# Index(['id', 'age', 'name'], dtype='str')
# 值
# [[1 20 'tom']
#  [2 30 'jack']
#  [3 40 'bob']
#  [4 50 'alice']
#  [5 10 'zoom']]
# 维度
# 2
# 数据类型
# id      int64
# age     int64
# name      str
# dtype: object
# 转置
#       学生1   学生2  学生3    学生4   学生5
# id      1     2    3      4     5
# age    20    30   40     50    10
# name  tom  jack  bob  alice  zoom

# %%
# 获取元素

# 获取某行
print(df.loc['学生2'])
print(df.iloc[1])

# 获取某列
print(df.loc[:,'name'])
print(df.iloc[:,2])
# Out:
# id         2
# age       30
# name    jack
# Name: 学生2, dtype: object
# id         2
# age       30
# name    jack
# Name: 学生2, dtype: object
# 学生1      tom
# 学生2     jack
# 学生3      bob
# 学生4    alice
# 学生5     zoom
# Name: name, dtype: str
# 学生1      tom
# 学生2     jack
# 学生3      bob
# 学生4    alice
# 学生5     zoom
# Name: name, dtype: str

# %%
# 获取单个元素
print(df.at['学生3','name'])
print(df.iat[2,2])
print(df.loc['学生3','name'])
print(df.iloc[2,2])
# Out:
# bob
# bob
# bob
# bob
