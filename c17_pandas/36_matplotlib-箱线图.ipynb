# %%
"""
箱线图
    IQR：四分位间距
    IQR = Q3 - Q1

    异常值：位于上下边缘意外的数值均属异常值，箱线图体检为 “点”
    上边缘线：计算公式=Q3 + 1.5*IQR
    上司分位/第三四分位（Q3）：从小到大排序在序列75%位置的值
    中位数/第二四分位（Q2）：数据从小到大排列后最中间位置的值，若总数量为偶数，中位数取中间两个数的均值
    下四分为/第一四分位（Q1）：从小到大排序后在序列25%的位置
    下边缘线：计算公式为=Q1-1.5*IQR


"""
# Out:
# '\n折线图：plot\n条形图：bar\n饼图：pie\n散点图：scatter\n箱线图：boxplot\n组合图\n'

# %%
import random
# 箱线图

import matplotlib.pyplot as plt
from matplotlib import rcParams # 字体

# 设置字体
rcParams['font.family'] = ['SimHei']
# 创建图表，设置大小
plt.figure(figsize=(10,8))



data = {
    '语文':[82,85,88,70,90,76,84,83,95],
    '数学':[75,80,79,93,88,82,87,89,92],
    '英语':[70,82,68,65,78,80,85,90,95]
}

plt.figure(figsize=(8,6))

plt.boxplot(data.values(),tick_labels=data.keys())

plt.title("各科成绩分布（箱线图）")
plt.ylabel('分数')
plt.grid(True,axis='y',linestyle='--',alpha=0.5)

# 显示图表
plt.show()

# %%
"""
折线图：趋势随时间变化
条形图/柱状图：类别之间比对
饼图：整体组成比例
散点图：两变量相关性
箱线图：数据分布，异常
"""
