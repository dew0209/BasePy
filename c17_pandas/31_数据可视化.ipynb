# %%
"""
数据可视化
    可视化基础
    Matplotlib
    Seaborn
    Pandas可视化

看见抽象的数据
让数据背后的规律，异常，趋势一目了然

信：准确表达，避免可视化的误导性
达：高效传达，有效信息直接高效传达
雅：赏心悦目，设计美观的可视化（布局，配色）

常见图表：
    柱状图
    折线图
    散点图
    条形图
    饼图
    箱型图
标题
坐标轴
图形要素
图例
数据标签

工具              说明                      优点                          缺点
matplotlib      python最基础的可视化库        灵活强大，定制分析               代码多，风格基础
seabom          基于matplotlib              风格美观，统计图方便             对简单图略繁琐
pandas plot     快速图标，调用.plot()         快捷，适合EDA                  图表样式较少
"""
