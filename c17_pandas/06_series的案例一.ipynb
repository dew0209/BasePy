# %%
"""
创建一个包含10名学生数学成绩的series，成绩范围在50~100之间。
计算平均分，最高分，最低分，并找出高于平均分的学生人数
"""

import pandas as pd
import numpy as np

np.random.seed(10)
values = np.random.randint(50,101,10)
scores = pd.Series(values, index=['学生' + str(i) for i in range(1,11)])
print(scores)
# Out:
# 学生1     59
# 学生2     86
# 学生3     65
# 学生4     50
# 学生5     99
# 学生6     78
# 学生7     75
# 学生8     79
# 学生9     98
# 学生10    79
# dtype: int32

# %%
print('平均分：',scores.mean())
print('最高分：',scores.max())
print('最低分：',scores.min())

print('大于平均的:')
print(scores[scores > scores.mean()])
print(scores[scores > scores.mean()].count())
# Out:
# 平均分： 76.8
# 最高分： 99
# 最低分： 50
# 大于平均的:
# 学生2     86
# 学生5     99
# 学生6     78
# 学生8     79
# 学生9     98
# 学生10    79
# dtype: int32
# 6
